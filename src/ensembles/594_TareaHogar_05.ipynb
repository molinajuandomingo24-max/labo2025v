# %% [markdown]
# <a href="https://colab.research.google.com/github/molinajuandomingo24-max/labo2025v/blob/main/src/ensembles/594_TareaHogar_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 09 01:43:54 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660356 35.3 1454482    77.7 1454482  77.7
# Vcells 1226517  9.4 8388608    64.0 1975136  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5941 # Cambiado a 5941 para nueva corrida
PARAM$semilla_primigenia <- 209353

# Definición de 5 semillas para estabilizar el resultado
PARAM$semillas_bo <- c(292267, 480731, 529681)
PARAM$indice_corrida <- 1 # Inicialización para el loop

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
# Parametros LightGBM fijos (mantengo la configuración actual)
PARAM$lgbm$param_fijos <- list(
  boosting= "gbdt",
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE,
  verbosity= -100,
  max_depth= -1L,
  min_gain_to_split= 0,
  min_sum_hessian_in_leaf= 0.001,
  lambda_l1= 0.0,
  lambda_l2= 0.0,
  max_bin= 31L,
  bagging_fraction= 1.0,
  pos_bagging_fraction= 1.0,
  neg_bagging_fraction= 1.0,
  is_unbalance= FALSE,
  scale_pos_weight= 1.0,
  drop_rate= 0.1,
  max_drop= 50,
  skip_drop= 0.5,
  extra_trees= FALSE,
  num_iterations= 1200,
  learning_rate= 0.02
  # Los 3 a optimizar no se colocan aquí, se definen en makeParamSet
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Definición de SOLO los 3 hiperparámetros principales a optimizar
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower= 16L, upper= 1024L), # Rango ajustado
  makeIntegerParam("min_data_in_leaf", lower= 1000L, upper= 8000L), # Rango ajustado
  makeNumericParam("feature_fraction", lower= 0.3, upper= 1.0) # Rango ajustado
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 30 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83349
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# La función EstimarGanancia_AUC_lightgbm se mantiene IGUAL
EstimarGanancia_AUC_lightgbm <- function(x) {

  # Obtener la semilla de la corrida actual
  semilla_actual <- PARAM$semillas_bo[PARAM$indice_corrida]

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)
  param_completo$seed <- semilla_actual # Asignar la semilla

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC, " (Semilla: ", semilla_actual, ")")

  return(AUC)
}

# %%
# Aquí comienza la configuración de la Bayesian Optimization

funcion_optimizar <- EstimarGanancia_AUC_lightgbm
configureMlr(show.learner.output= FALSE)

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar,
  minimize= FALSE,
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs,
  has.simple.signature= FALSE
)

# Definir el control MBO fuera del loop
kbayesiana_base <- "bayesiana"
ctrl <- makeMBOControl(save.on.disk.at.time= 600)
ctrl <- setMBOControlTermination(ctrl, iters= PARAM$hyperparametertuning$iteraciones)
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# Inicializo variables para rastrear el mejor resultado global
best_global_AUC <- -1
best_global_hyperparams <- NULL
resultados_semillas <- data.table()

# Loop para correr la BO con cada semilla
for (s in 1:length(PARAM$semillas_bo)) {

  PARAM$indice_corrida <- s
  semilla_actual <- PARAM$semillas_bo[s]
  kbayesiana <- paste0(kbayesiana_base, "_s", semilla_actual, ".RDATA")

  message(format(Sys.time(), "%a %b %d %X %Y"), " --- INICIANDO CORRIDA CON SEMILLA: ", semilla_actual, " ---")

if (file.exists(kbayesiana)) {
    # Si el archivo EXISTE, se REANUDA la optimización anterior
    message("Archivo de guardado encontrado: ", kbayesiana, ". Reanudando optimización.")
    # Usamos mboContinue() para retomar el trabajo guardado
    bayesiana_salida <- mboContinue(kbayesiana)

  } else {
    # Si el archivo NO existe, se INICIA una nueva optimización
    message("Archivo de guardado NO encontrado. Iniciando nueva optimización.")

  # Establecer la semilla para mlrMBO
  set.seed(semilla_actual)
  ctrl$save.file.path <- kbayesiana # Actualizar el path de guardado

  # inicio la optimizacion bayesiana
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)

  # Proceso el resultado de la corrida actual
  tb_bayesiana_actual <- as.data.table(bayesiana_salida$opt.path)
  setorder(tb_bayesiana_actual, -y)

  # Registro el mejor AUC de esta corrida
  mejor_auc_corrida <- tb_bayesiana_actual[1, y]

  # Guardo el resultado para el análisis global
  tb_bayesiana_actual[, iter := .I]
  tb_bayesiana_actual[, semilla := semilla_actual]
  resultados_semillas <- rbind(resultados_semillas, tb_bayesiana_actual, fill=TRUE)

  # Verifico si es el mejor resultado global
  if (mejor_auc_corrida > best_global_AUC) {
    best_global_AUC <- mejor_auc_corrida
    best_global_hyperparams <- tb_bayesiana_actual[
      1,
      setdiff(colnames(tb_bayesiana_actual),
        c("y","dob","eol","error.message","exec.time","ei","error.model",
          "train.time","prop.type","propose.time","se","mean","iter", "semilla")),
      with= FALSE
    ]
  }
}

# Almaceno los resultados finales de las 3 corridas

# Guardo el log completo de todas las semillas
fwrite(resultados_semillas,
  file= "BO_log_multi_semilla.txt",
  sep= "\t"
)

# Los mejores hiperparámetros globales
PARAM$out$lgbm$mejores_hiperparametros <- best_global_hyperparams
PARAM$out$lgbm$y_global <- best_global_AUC

write_yaml( PARAM, file="PARAM.yml")

print("Mejores Hiperparámetros Globales (entre 3 semillas):")
print(PARAM$out$lgbm$mejores_hiperparametros)
print(paste("Mejor AUC Global:", PARAM$out$lgbm$y_global))
# Out:
# Sun Nov 09 02:56:04 PM 2025 --- INICIANDO CORRIDA CON SEMILLA: 292267 ---
#
# Computing y column(s) for design. Not provided.
#
# Sun Nov 09 03:00:17 PM 2025 AUC 0.926023367462703 (Semilla: 292267)
#
# Sun Nov 09 03:03:10 PM 2025 AUC 0.924137479428862 (Semilla: 292267)
#
# Sun Nov 09 03:05:30 PM 2025 AUC 0.927286369955224 (Semilla: 292267)
#
# Sun Nov 09 03:10:10 PM 2025 AUC 0.927258768850418 (Semilla: 292267)
#
# Sun Nov 09 03:13:16 PM 2025 AUC 0.928768755616004 (Semilla: 292267)
#
# Sun Nov 09 03:15:43 PM 2025 AUC 0.926286666503888 (Semilla: 292267)
#
# Sun Nov 09 03:19:38 PM 2025 AUC 0.9250604989625 (Semilla: 292267)
#
# Sun Nov 09 03:23:07 PM 2025 AUC 0.926072212560712 (Semilla: 292267)
#
# Sun Nov 09 03:25:45 PM 2025 AUC 0.926758280523801 (Semilla: 292267)
#
# Sun Nov 09 03:28:01 PM 2025 AUC 0.925991943075457 (Semilla: 292267)
#
# Sun Nov 09 03:30:01 PM 2025 AUC 0.924471405116245 (Semilla: 292267)
#
# Sun Nov 09 03:34:13 PM 2025 AUC 0.928604132241402 (Semilla: 292267)
#
# [mbo] 0: num_leaves=300; min_data_in_leaf=2970; feature_fraction=0.566 : y = 0.926 : 253.3 secs : initdesign
#
# [mbo] 0: num_leaves=425; min_data_in_leaf=7388; feature_fraction=0.607 : y = 0.924 : 172.6 secs : initdesign
#
# [mbo] 0: num_leaves=608; min_data_in_leaf=4773; feature_fraction=0.79 : y = 0.927 : 140.8 secs : initdesign
#
# [mbo] 0: num_leaves=493; min_data_in_leaf=2251; feature_fraction=0.524 : y = 0.927 : 279.7 secs : initdesign
#
# [mbo] 0: num_leaves=797; min_data_in_leaf=1902; feature_fraction=0.754 : y = 0.929 : 186.2 secs : initdesign
#
# [mbo] 0: num_leaves=221; min_data_in_leaf=4233; feature_fraction=0.989 : y = 0.926 : 146.6 secs : initdesign
#
# [mbo] 0: num_leaves=568; min_data_in_leaf=6275; feature_fraction=0.434 : y = 0.925 : 235.2 secs : initdesign
#
# [mbo] 0: num_leaves=1010; min_data_in_leaf=5577; feature_fraction=0.323 : y = 0.926 : 209.2 secs : initdesign
#
# [mbo] 0: num_leaves=113; min_data_in_leaf=3503; feature_fraction=0.654 : y = 0.927 : 158.1 secs : initdesign
#
# [mbo] 0: num_leaves=912; min_data_in_leaf=5736; feature_fraction=0.839 : y = 0.926 : 135.3 secs : initdesign
#
# [mbo] 0: num_leaves=25; min_data_in_leaf=7830; feature_fraction=0.924 : y = 0.924 : 120.3 secs : initdesign
#
# [mbo] 0: num_leaves=723; min_data_in_leaf=1562; feature_fraction=0.36 : y = 0.929 : 251.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 03:38:05 PM 2025 AUC 0.92866360134898 (Semilla: 292267)
#
# [mbo] 1: num_leaves=755; min_data_in_leaf=1000; feature_fraction=0.85 : y = 0.929 : 231.3 secs : infill_ei
#
# Sun Nov 09 03:43:12 PM 2025 AUC 0.928919695540783 (Semilla: 292267)
#
# [mbo] 2: num_leaves=906; min_data_in_leaf=1176; feature_fraction=0.535 : y = 0.929 : 306.8 secs : infill_ei
#
# Sun Nov 09 03:46:34 PM 2025 AUC 0.928875250790159 (Semilla: 292267)
#
# [mbo] 3: num_leaves=1024; min_data_in_leaf=1472; feature_fraction=0.772 : y = 0.929 : 202.1 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 03:50:00 PM 2025 AUC 0.928293433397566 (Semilla: 292267)
#
# [mbo] 4: num_leaves=752; min_data_in_leaf=1313; feature_fraction=0.687 : y = 0.928 : 205.4 secs : infill_ei
#
# Sun Nov 09 03:53:52 PM 2025 AUC 0.927317524250123 (Semilla: 292267)
#
# [mbo] 5: num_leaves=1024; min_data_in_leaf=1816; feature_fraction=0.305 : y = 0.927 : 231.1 secs : infill_ei
#
# Sun Nov 09 03:58:47 PM 2025 AUC 0.929472202919527 (Semilla: 292267)
#
# [mbo] 6: num_leaves=920; min_data_in_leaf=1000; feature_fraction=0.447 : y = 0.929 : 294.7 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 04:03:38 PM 2025 AUC 0.929707189138795 (Semilla: 292267)
#
# [mbo] 7: num_leaves=714; min_data_in_leaf=1000; feature_fraction=0.437 : y = 0.93 : 290.4 secs : infill_ei
#
# Sun Nov 09 04:08:11 PM 2025 AUC 0.929794297756779 (Semilla: 292267)
#
# [mbo] 8: num_leaves=412; min_data_in_leaf=1000; feature_fraction=0.383 : y = 0.93 : 273.0 secs : infill_ei
#
# Sun Nov 09 04:12:06 PM 2025 AUC 0.929303498042666 (Semilla: 292267)
#
# [mbo] 9: num_leaves=17; min_data_in_leaf=1000; feature_fraction=0.405 : y = 0.929 : 234.1 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 04:15:14 PM 2025 AUC 0.928397048907431 (Semilla: 292267)
#
# [mbo] 10: num_leaves=1024; min_data_in_leaf=1814; feature_fraction=1 : y = 0.928 : 187.9 secs : infill_ei
#
# Sun Nov 09 04:19:48 PM 2025 AUC 0.928353163844438 (Semilla: 292267)
#
# [mbo] 11: num_leaves=590; min_data_in_leaf=1000; feature_fraction=0.383 : y = 0.928 : 273.4 secs : infill_ei
#
# Sun Nov 09 04:24:28 PM 2025 AUC 0.929961969531067 (Semilla: 292267)
#
# [mbo] 12: num_leaves=285; min_data_in_leaf=1000; feature_fraction=0.412 : y = 0.93 : 280.2 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 04:28:39 PM 2025 AUC 0.929121083897477 (Semilla: 292267)
#
# [mbo] 13: num_leaves=227; min_data_in_leaf=1000; feature_fraction=0.318 : y = 0.929 : 250.5 secs : infill_ei
#
# Sun Nov 09 04:33:27 PM 2025 AUC 0.929163453669031 (Semilla: 292267)
#
# [mbo] 14: num_leaves=369; min_data_in_leaf=1000; feature_fraction=0.433 : y = 0.929 : 287.5 secs : infill_ei
#
# Sun Nov 09 04:37:18 PM 2025 AUC 0.928601327225084 (Semilla: 292267)
#
# [mbo] 15: num_leaves=281; min_data_in_leaf=1000; feature_fraction=0.992 : y = 0.929 : 230.1 secs : infill_ei
#
# Saved the current state after iteration 16 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 04:41:48 PM 2025 AUC 0.929206430968406 (Semilla: 292267)
#
# [mbo] 16: num_leaves=278; min_data_in_leaf=1000; feature_fraction=0.382 : y = 0.929 : 269.9 secs : infill_ei
#
# Sun Nov 09 04:46:06 PM 2025 AUC 0.929614283827627 (Semilla: 292267)
#
# [mbo] 17: num_leaves=303; min_data_in_leaf=1001; feature_fraction=0.338 : y = 0.93 : 258.0 secs : infill_ei
#
# Sun Nov 09 04:50:08 PM 2025 AUC 0.928937965688116 (Semilla: 292267)
#
# [mbo] 18: num_leaves=413; min_data_in_leaf=1415; feature_fraction=0.33 : y = 0.929 : 241.1 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 04:53:59 PM 2025 AUC 0.927366511894932 (Semilla: 292267)
#
# [mbo] 19: num_leaves=578; min_data_in_leaf=1000; feature_fraction=1 : y = 0.927 : 230.7 secs : infill_ei
#
# Sun Nov 09 04:58:36 PM 2025 AUC 0.929759358106956 (Semilla: 292267)
#
# [mbo] 20: num_leaves=291; min_data_in_leaf=1004; feature_fraction=0.4 : y = 0.93 : 277.0 secs : infill_ei
#
# Sun Nov 09 05:03:34 PM 2025 AUC 0.928353041067836 (Semilla: 292267)
#
# [mbo] 21: num_leaves=798; min_data_in_leaf=1000; feature_fraction=0.462 : y = 0.928 : 297.1 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 05:05:39 PM 2025 AUC 0.924535210320134 (Semilla: 292267)
#
# [mbo] 22: num_leaves=987; min_data_in_leaf=7552; feature_fraction=0.749 : y = 0.925 : 124.9 secs : infill_ei
#
# Sun Nov 09 05:09:30 PM 2025 AUC 0.927942513592344 (Semilla: 292267)
#
# [mbo] 23: num_leaves=400; min_data_in_leaf=1001; feature_fraction=0.909 : y = 0.928 : 230.8 secs : infill_ei
#
# Sun Nov 09 05:14:20 PM 2025 AUC 0.929571074977974 (Semilla: 292267)
#
# [mbo] 24: num_leaves=139; min_data_in_leaf=1001; feature_fraction=0.436 : y = 0.93 : 289.0 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 05:18:50 PM 2025 AUC 0.928507625820299 (Semilla: 292267)
#
# [mbo] 25: num_leaves=877; min_data_in_leaf=1367; feature_fraction=0.418 : y = 0.929 : 269.6 secs : infill_ei
#
# Sun Nov 09 05:23:22 PM 2025 AUC 0.928752313702054 (Semilla: 292267)
#
# [mbo] 26: num_leaves=303; min_data_in_leaf=1591; feature_fraction=0.436 : y = 0.929 : 271.6 secs : infill_ei
#
# Sun Nov 09 05:27:31 PM 2025 AUC 0.925321689056741 (Semilla: 292267)
#
# [mbo] 27: num_leaves=897; min_data_in_leaf=6621; feature_fraction=0.527 : y = 0.925 : 248.3 secs : infill_ei
#
# Saved the current state after iteration 28 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 05:32:36 PM 2025 AUC 0.929272713233708 (Semilla: 292267)
#
# [mbo] 28: num_leaves=1024; min_data_in_leaf=1001; feature_fraction=0.481 : y = 0.929 : 304.8 secs : infill_ei
#
# Sun Nov 09 05:37:02 PM 2025 AUC 0.929207512136539 (Semilla: 292267)
#
# [mbo] 29: num_leaves=397; min_data_in_leaf=1004; feature_fraction=0.358 : y = 0.929 : 265.6 secs : infill_ei
#
# Sun Nov 09 05:40:48 PM 2025 AUC 0.929312400979013 (Semilla: 292267)
#
# [mbo] 30: num_leaves=281; min_data_in_leaf=1002; feature_fraction=0.771 : y = 0.929 : 226.2 secs : infill_ei
#
# Saved the final state in the file bayesiana_s292267.RDATA
#
# Saved the final state in the file bayesiana_s292267.RDATA
#
# Sun Nov 09 05:40:49 PM 2025 --- INICIANDO CORRIDA CON SEMILLA: 480731 ---
#
# Computing y column(s) for design. Not provided.
#
# Sun Nov 09 05:43:39 PM 2025 AUC 0.925658341836816 (Semilla: 480731)
#
# Sun Nov 09 05:47:50 PM 2025 AUC 0.927882371044252 (Semilla: 480731)
#
# Sun Nov 09 05:51:56 PM 2025 AUC 0.926661512198316 (Semilla: 480731)
#
# Sun Nov 09 05:54:10 PM 2025 AUC 0.925810994046117 (Semilla: 480731)
#
# Sun Nov 09 05:57:34 PM 2025 AUC 0.92484845813827 (Semilla: 480731)
#
# Sun Nov 09 06:01:06 PM 2025 AUC 0.927055768782755 (Semilla: 480731)
#
# Sun Nov 09 06:03:46 PM 2025 AUC 0.927108054397008 (Semilla: 480731)
#
# Sun Nov 09 06:07:53 PM 2025 AUC 0.924881933292519 (Semilla: 480731)
#
# Sun Nov 09 06:11:27 PM 2025 AUC 0.927974871427444 (Semilla: 480731)
#
# Sun Nov 09 06:13:30 PM 2025 AUC 0.924492602418137 (Semilla: 480731)
#
# Sun Nov 09 06:17:47 PM 2025 AUC 0.928290372379482 (Semilla: 480731)
#
# Sun Nov 09 06:19:59 PM 2025 AUC 0.925073735632993 (Semilla: 480731)
#
# [mbo] 0: num_leaves=601; min_data_in_leaf=2488; feature_fraction=0.678 : y = 0.926 : 170.5 secs : initdesign
#
# [mbo] 0: num_leaves=644; min_data_in_leaf=3895; feature_fraction=0.553 : y = 0.928 : 250.9 secs : initdesign
#
# [mbo] 0: num_leaves=724; min_data_in_leaf=4750; feature_fraction=0.456 : y = 0.927 : 245.6 secs : initdesign
#
# [mbo] 0: num_leaves=226; min_data_in_leaf=5633; feature_fraction=0.709 : y = 0.926 : 134.5 secs : initdesign
#
# [mbo] 0: num_leaves=40; min_data_in_leaf=7025; feature_fraction=0.333 : y = 0.925 : 203.5 secs : initdesign
#
# [mbo] 0: num_leaves=870; min_data_in_leaf=4482; feature_fraction=0.594 : y = 0.927 : 212.1 secs : initdesign
#
# [mbo] 0: num_leaves=497; min_data_in_leaf=2897; feature_fraction=0.774 : y = 0.927 : 160.4 secs : initdesign
#
# [mbo] 0: num_leaves=280; min_data_in_leaf=6561; feature_fraction=0.521 : y = 0.925 : 246.8 secs : initdesign
#
# [mbo] 0: num_leaves=832; min_data_in_leaf=1233; feature_fraction=0.953 : y = 0.928 : 213.5 secs : initdesign
#
# [mbo] 0: num_leaves=135; min_data_in_leaf=7557; feature_fraction=0.882 : y = 0.924 : 123.6 secs : initdesign
#
# [mbo] 0: num_leaves=361; min_data_in_leaf=1940; feature_fraction=0.401 : y = 0.928 : 256.6 secs : initdesign
#
# [mbo] 0: num_leaves=1020; min_data_in_leaf=5776; feature_fraction=0.93 : y = 0.925 : 132.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 06:24:00 PM 2025 AUC 0.927647030424781 (Semilla: 480731)
#
# [mbo] 1: num_leaves=272; min_data_in_leaf=1633; feature_fraction=0.334 : y = 0.928 : 241.2 secs : infill_ei
#
# Sun Nov 09 06:28:06 PM 2025 AUC 0.928272578682491 (Semilla: 480731)
#
# [mbo] 2: num_leaves=370; min_data_in_leaf=2936; feature_fraction=0.415 : y = 0.928 : 244.6 secs : infill_ei
#
# Sun Nov 09 06:32:18 PM 2025 AUC 0.927682486460266 (Semilla: 480731)
#
# [mbo] 3: num_leaves=854; min_data_in_leaf=2405; feature_fraction=0.417 : y = 0.928 : 252.0 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 06:36:25 PM 2025 AUC 0.926438971347004 (Semilla: 480731)
#
# [mbo] 4: num_leaves=512; min_data_in_leaf=2481; feature_fraction=0.402 : y = 0.926 : 246.1 secs : infill_ei
#
# Sun Nov 09 06:40:16 PM 2025 AUC 0.926248645392382 (Semilla: 480731)
#
# [mbo] 5: num_leaves=400; min_data_in_leaf=3722; feature_fraction=0.581 : y = 0.926 : 230.9 secs : infill_ei
#
# Sun Nov 09 06:44:13 PM 2025 AUC 0.927250167427583 (Semilla: 480731)
#
# [mbo] 6: num_leaves=347; min_data_in_leaf=2773; feature_fraction=0.373 : y = 0.927 : 237.2 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 06:48:45 PM 2025 AUC 0.927678339102418 (Semilla: 480731)
#
# [mbo] 7: num_leaves=373; min_data_in_leaf=1408; feature_fraction=0.416 : y = 0.928 : 271.6 secs : infill_ei
#
# Sun Nov 09 06:52:29 PM 2025 AUC 0.928523266551599 (Semilla: 480731)
#
# [mbo] 8: num_leaves=960; min_data_in_leaf=2039; feature_fraction=0.3 : y = 0.929 : 223.7 secs : infill_ei
#
# Sun Nov 09 06:56:03 PM 2025 AUC 0.927084427105685 (Semilla: 480731)
#
# [mbo] 9: num_leaves=819; min_data_in_leaf=3034; feature_fraction=0.3 : y = 0.927 : 213.4 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 07:00:05 PM 2025 AUC 0.928020056388938 (Semilla: 480731)
#
# [mbo] 10: num_leaves=789; min_data_in_leaf=1886; feature_fraction=0.345 : y = 0.928 : 241.2 secs : infill_ei
#
# Sun Nov 09 07:03:48 PM 2025 AUC 0.92819756947265 (Semilla: 480731)
#
# [mbo] 11: num_leaves=1021; min_data_in_leaf=2198; feature_fraction=0.3 : y = 0.928 : 222.9 secs : infill_ei
#
# Sun Nov 09 07:08:30 PM 2025 AUC 0.928467148960303 (Semilla: 480731)
#
# [mbo] 12: num_leaves=924; min_data_in_leaf=2047; feature_fraction=0.523 : y = 0.928 : 281.8 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 07:12:07 PM 2025 AUC 0.927655456905748 (Semilla: 480731)
#
# [mbo] 13: num_leaves=259; min_data_in_leaf=3076; feature_fraction=0.302 : y = 0.928 : 215.9 secs : infill_ei
#
# Sun Nov 09 07:15:58 PM 2025 AUC 0.928911745490184 (Semilla: 480731)
#
# [mbo] 14: num_leaves=468; min_data_in_leaf=1855; feature_fraction=0.302 : y = 0.929 : 230.7 secs : infill_ei
#
# Sun Nov 09 07:20:08 PM 2025 AUC 0.928060956084081 (Semilla: 480731)
#
# [mbo] 15: num_leaves=498; min_data_in_leaf=1725; feature_fraction=0.371 : y = 0.928 : 249.3 secs : infill_ei
#
# Saved the current state after iteration 16 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 07:24:36 PM 2025 AUC 0.928696438240208 (Semilla: 480731)
#
# [mbo] 16: num_leaves=1014; min_data_in_leaf=1956; feature_fraction=0.444 : y = 0.929 : 267.6 secs : infill_ei
#
# Sun Nov 09 07:28:33 PM 2025 AUC 0.927725714484772 (Semilla: 480731)
#
# [mbo] 17: num_leaves=481; min_data_in_leaf=1435; feature_fraction=0.302 : y = 0.928 : 236.3 secs : infill_ei
#
# Sun Nov 09 07:31:43 PM 2025 AUC 0.926839002901323 (Semilla: 480731)
#
# [mbo] 18: num_leaves=1023; min_data_in_leaf=1866; feature_fraction=0.997 : y = 0.927 : 190.4 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 07:35:30 PM 2025 AUC 0.928239472207657 (Semilla: 480731)
#
# [mbo] 19: num_leaves=492; min_data_in_leaf=1940; feature_fraction=0.301 : y = 0.928 : 226.4 secs : infill_ei
#
# Sun Nov 09 07:39:17 PM 2025 AUC 0.928168303619854 (Semilla: 480731)
#
# [mbo] 20: num_leaves=368; min_data_in_leaf=1835; feature_fraction=0.301 : y = 0.928 : 226.3 secs : infill_ei
#
# Sun Nov 09 07:43:51 PM 2025 AUC 0.929021460249439 (Semilla: 480731)
#
# [mbo] 21: num_leaves=440; min_data_in_leaf=1871; feature_fraction=0.452 : y = 0.929 : 273.5 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 07:47:36 PM 2025 AUC 0.928429759506605 (Semilla: 480731)
#
# [mbo] 22: num_leaves=454; min_data_in_leaf=2149; feature_fraction=0.302 : y = 0.928 : 224.4 secs : infill_ei
#
# Sun Nov 09 07:51:59 PM 2025 AUC 0.928463429654315 (Semilla: 480731)
#
# [mbo] 23: num_leaves=914; min_data_in_leaf=1576; feature_fraction=0.404 : y = 0.928 : 262.3 secs : infill_ei
#
# Sun Nov 09 07:55:07 PM 2025 AUC 0.928319293949129 (Semilla: 480731)
#
# [mbo] 24: num_leaves=445; min_data_in_leaf=1851; feature_fraction=0.812 : y = 0.928 : 187.6 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 07:59:04 PM 2025 AUC 0.929153478880188 (Semilla: 480731)
#
# [mbo] 25: num_leaves=1016; min_data_in_leaf=1354; feature_fraction=0.301 : y = 0.929 : 236.9 secs : infill_ei
#
# Sun Nov 09 08:03:46 PM 2025 AUC 0.928348438991409 (Semilla: 480731)
#
# [mbo] 26: num_leaves=996; min_data_in_leaf=1152; feature_fraction=0.415 : y = 0.928 : 281.0 secs : infill_ei
#
# Sun Nov 09 08:07:41 PM 2025 AUC 0.929720909323242 (Semilla: 480731)
#
# [mbo] 27: num_leaves=1024; min_data_in_leaf=1540; feature_fraction=0.301 : y = 0.93 : 234.4 secs : infill_ei
#
# Saved the current state after iteration 28 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 08:10:44 PM 2025 AUC 0.928834905505324 (Semilla: 480731)
#
# [mbo] 28: num_leaves=152; min_data_in_leaf=1975; feature_fraction=0.916 : y = 0.929 : 183.0 secs : infill_ei
#
# Sun Nov 09 08:13:03 PM 2025 AUC 0.925239062385807 (Semilla: 480731)
#
# [mbo] 29: num_leaves=380; min_data_in_leaf=5958; feature_fraction=0.656 : y = 0.925 : 138.4 secs : infill_ei
#
# Sun Nov 09 08:17:39 PM 2025 AUC 0.928961859061185 (Semilla: 480731)
#
# [mbo] 30: num_leaves=71; min_data_in_leaf=1955; feature_fraction=0.55 : y = 0.929 : 274.8 secs : infill_ei
#
# Saved the final state in the file bayesiana_s480731.RDATA
#
# Sun Nov 09 08:17:39 PM 2025 --- INICIANDO CORRIDA CON SEMILLA: 529681 ---
#
# Computing y column(s) for design. Not provided.
#
# Sun Nov 09 08:21:14 PM 2025 AUC 0.927869631694428 (Semilla: 529681)
#
# Sun Nov 09 08:23:24 PM 2025 AUC 0.92482948263214 (Semilla: 529681)
#
# Sun Nov 09 08:26:21 PM 2025 AUC 0.927691008991105 (Semilla: 529681)
#
# Sun Nov 09 08:30:31 PM 2025 AUC 0.926802590451527 (Semilla: 529681)
#
# Sun Nov 09 08:33:36 PM 2025 AUC 0.925898688627466 (Semilla: 529681)
#
# Sun Nov 09 08:37:14 PM 2025 AUC 0.926475081577194 (Semilla: 529681)
#
# Sun Nov 09 08:40:21 PM 2025 AUC 0.927840855233608 (Semilla: 529681)
#
# Sun Nov 09 08:42:26 PM 2025 AUC 0.924273229629505 (Semilla: 529681)
#
# Sun Nov 09 08:46:58 PM 2025 AUC 0.929103246573033 (Semilla: 529681)
#
# Sun Nov 09 08:49:08 PM 2025 AUC 0.92500452501976 (Semilla: 529681)
#
# Sun Nov 09 08:51:44 PM 2025 AUC 0.927223947639287 (Semilla: 529681)
#
# Sun Nov 09 08:55:32 PM 2025 AUC 0.924369535193874 (Semilla: 529681)
#
# [mbo] 0: num_leaves=452; min_data_in_leaf=3398; feature_fraction=0.308 : y = 0.928 : 215.4 secs : initdesign
#
# [mbo] 0: num_leaves=816; min_data_in_leaf=6645; feature_fraction=0.669 : y = 0.925 : 129.9 secs : initdesign
#
# [mbo] 0: num_leaves=272; min_data_in_leaf=2186; feature_fraction=0.778 : y = 0.928 : 177.0 secs : initdesign
#
# [mbo] 0: num_leaves=627; min_data_in_leaf=4917; feature_fraction=0.477 : y = 0.927 : 250.3 secs : initdesign
#
# [mbo] 0: num_leaves=256; min_data_in_leaf=5215; feature_fraction=0.603 : y = 0.926 : 184.6 secs : initdesign
#
# [mbo] 0: num_leaves=993; min_data_in_leaf=4295; feature_fraction=0.582 : y = 0.926 : 217.7 secs : initdesign
#
# [mbo] 0: num_leaves=378; min_data_in_leaf=1783; feature_fraction=0.951 : y = 0.928 : 187.7 secs : initdesign
#
# [mbo] 0: num_leaves=122; min_data_in_leaf=7252; feature_fraction=0.866 : y = 0.924 : 124.2 secs : initdesign
#
# [mbo] 0: num_leaves=557; min_data_in_leaf=1218; feature_fraction=0.406 : y = 0.929 : 272.0 secs : initdesign
#
# [mbo] 0: num_leaves=722; min_data_in_leaf=6215; feature_fraction=0.9 : y = 0.925 : 130.0 secs : initdesign
#
# [mbo] 0: num_leaves=31; min_data_in_leaf=3255; feature_fraction=0.754 : y = 0.927 : 156.4 secs : initdesign
#
# [mbo] 0: num_leaves=869; min_data_in_leaf=7657; feature_fraction=0.422 : y = 0.924 : 227.8 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 08:59:39 PM 2025 AUC 0.928738560987005 (Semilla: 529681)
#
# [mbo] 1: num_leaves=643; min_data_in_leaf=1000; feature_fraction=0.3 : y = 0.929 : 246.8 secs : infill_ei
#
# Sun Nov 09 09:04:43 PM 2025 AUC 0.929998649478534 (Semilla: 529681)
#
# [mbo] 2: num_leaves=522; min_data_in_leaf=1000; feature_fraction=0.477 : y = 0.93 : 304.0 secs : infill_ei
#
# Sun Nov 09 09:08:57 PM 2025 AUC 0.929203556951995 (Semilla: 529681)
#
# [mbo] 3: num_leaves=16; min_data_in_leaf=1000; feature_fraction=0.531 : y = 0.929 : 252.8 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 09:14:09 PM 2025 AUC 0.929049978879608 (Semilla: 529681)
#
# [mbo] 4: num_leaves=612; min_data_in_leaf=1000; feature_fraction=0.515 : y = 0.929 : 312.4 secs : infill_ei
#
# Sun Nov 09 09:19:00 PM 2025 AUC 0.928538229626847 (Semilla: 529681)
#
# [mbo] 5: num_leaves=392; min_data_in_leaf=1000; feature_fraction=0.442 : y = 0.929 : 290.4 secs : infill_ei
#
# Saved the current state after iteration 6 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 09:22:48 PM 2025 AUC 0.928493983004969 (Semilla: 529681)
#
# [mbo] 6: num_leaves=503; min_data_in_leaf=1001; feature_fraction=0.687 : y = 0.928 : 227.2 secs : infill_ei
#
# Sun Nov 09 09:28:02 PM 2025 AUC 0.929608608615849 (Semilla: 529681)
#
# [mbo] 7: num_leaves=499; min_data_in_leaf=1000; feature_fraction=0.509 : y = 0.93 : 313.9 secs : infill_ei
#
# Sun Nov 09 09:32:05 PM 2025 AUC 0.929485227849673 (Semilla: 529681)
#
# [mbo] 8: num_leaves=54; min_data_in_leaf=1000; feature_fraction=0.3 : y = 0.929 : 242.3 secs : infill_ei
#
# Saved the current state after iteration 9 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 09:37:02 PM 2025 AUC 0.92868247888205 (Semilla: 529681)
#
# [mbo] 9: num_leaves=131; min_data_in_leaf=1001; feature_fraction=0.452 : y = 0.929 : 296.7 secs : infill_ei
#
# Sun Nov 09 09:40:52 PM 2025 AUC 0.928431606892971 (Semilla: 529681)
#
# [mbo] 10: num_leaves=1024; min_data_in_leaf=1000; feature_fraction=1 : y = 0.928 : 230.4 secs : infill_ei
#
# Sun Nov 09 09:44:25 PM 2025 AUC 0.927370635831982 (Semilla: 529681)
#
# [mbo] 11: num_leaves=16; min_data_in_leaf=2451; feature_fraction=0.3 : y = 0.927 : 212.1 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 09:48:48 PM 2025 AUC 0.929593991485583 (Semilla: 529681)
#
# [mbo] 12: num_leaves=526; min_data_in_leaf=1000; feature_fraction=0.353 : y = 0.93 : 262.9 secs : infill_ei
#
# Sun Nov 09 09:52:34 PM 2025 AUC 0.928614053876246 (Semilla: 529681)
#
# [mbo] 13: num_leaves=56; min_data_in_leaf=1001; feature_fraction=1 : y = 0.929 : 225.8 secs : infill_ei
#
# Sun Nov 09 09:57:35 PM 2025 AUC 0.929146613684469 (Semilla: 529681)
#
# [mbo] 14: num_leaves=885; min_data_in_leaf=1000; feature_fraction=0.46 : y = 0.929 : 300.1 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 10:01:47 PM 2025 AUC 0.928282456526315 (Semilla: 529681)
#
# [mbo] 15: num_leaves=1024; min_data_in_leaf=1000; feature_fraction=0.31 : y = 0.928 : 251.8 secs : infill_ei
#
# Sun Nov 09 10:05:00 PM 2025 AUC 0.928298484934565 (Semilla: 529681)
#
# [mbo] 16: num_leaves=948; min_data_in_leaf=1773; feature_fraction=0.685 : y = 0.928 : 192.4 secs : infill_ei
#
# Sun Nov 09 10:10:06 PM 2025 AUC 0.929116206486505 (Semilla: 529681)
#
# [mbo] 17: num_leaves=107; min_data_in_leaf=1002; feature_fraction=0.492 : y = 0.929 : 305.5 secs : infill_ei
#
# Saved the current state after iteration 18 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 10:15:12 PM 2025 AUC 0.929404999989487 (Semilla: 529681)
#
# [mbo] 18: num_leaves=764; min_data_in_leaf=1000; feature_fraction=0.475 : y = 0.929 : 306.0 secs : infill_ei
#
# Sun Nov 09 10:19:07 PM 2025 AUC 0.929053367196364 (Semilla: 529681)
#
# [mbo] 19: num_leaves=839; min_data_in_leaf=1001; feature_fraction=0.999 : y = 0.929 : 234.2 secs : infill_ei
#
# Sun Nov 09 10:23:15 PM 2025 AUC 0.929489449209765 (Semilla: 529681)
#
# [mbo] 20: num_leaves=820; min_data_in_leaf=1007; feature_fraction=0.3 : y = 0.929 : 247.9 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 10:26:59 PM 2025 AUC 0.928184056601193 (Semilla: 529681)
#
# [mbo] 21: num_leaves=817; min_data_in_leaf=2211; feature_fraction=0.302 : y = 0.928 : 223.7 secs : infill_ei
#
# Sun Nov 09 10:30:48 PM 2025 AUC 0.928909528013696 (Semilla: 529681)
#
# [mbo] 22: num_leaves=824; min_data_in_leaf=1001; feature_fraction=0.676 : y = 0.929 : 228.3 secs : infill_ei
#
# Sun Nov 09 10:33:40 PM 2025 AUC 0.927460144619998 (Semilla: 529681)
#
# [mbo] 23: num_leaves=850; min_data_in_leaf=2431; feature_fraction=1 : y = 0.927 : 171.4 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 10:38:36 PM 2025 AUC 0.928589583038909 (Semilla: 529681)
#
# [mbo] 24: num_leaves=528; min_data_in_leaf=1000; feature_fraction=0.458 : y = 0.929 : 295.3 secs : infill_ei
#
# Sun Nov 09 10:40:48 PM 2025 AUC 0.925004347769335 (Semilla: 529681)
#
# [mbo] 25: num_leaves=714; min_data_in_leaf=6235; feature_fraction=0.787 : y = 0.925 : 131.3 secs : infill_ei
#
# Sun Nov 09 10:44:06 PM 2025 AUC 0.923988440299763 (Semilla: 529681)
#
# [mbo] 26: num_leaves=671; min_data_in_leaf=7276; feature_fraction=0.308 : y = 0.924 : 197.8 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 10:48:33 PM 2025 AUC 0.929388923535937 (Semilla: 529681)
#
# [mbo] 27: num_leaves=190; min_data_in_leaf=1000; feature_fraction=0.37 : y = 0.929 : 267.1 secs : infill_ei
#
# Sun Nov 09 10:52:30 PM 2025 AUC 0.927019813525331 (Semilla: 529681)
#
# [mbo] 28: num_leaves=32; min_data_in_leaf=5162; feature_fraction=0.423 : y = 0.927 : 236.4 secs : infill_ei
#
# Sun Nov 09 10:57:11 PM 2025 AUC 0.929889516964883 (Semilla: 529681)
#
# [mbo] 29: num_leaves=1024; min_data_in_leaf=1001; feature_fraction=0.387 : y = 0.93 : 280.1 secs : infill_ei
#
# Saved the current state after iteration 30 in the file bayesiana_s529681.RDATA.
#
# Sun Nov 09 11:01:02 PM 2025 AUC 0.927889959249924 (Semilla: 529681)
#
# [mbo] 30: num_leaves=854; min_data_in_leaf=3268; feature_fraction=0.362 : y = 0.928 : 230.7 secs : infill_ei
#
# Saved the final state in the file bayesiana_s529681.RDATA
# [1] "Mejores Hiperparámetros Globales (entre 3 semillas):"
#    num_leaves min_data_in_leaf feature_fraction
#         <int>            <int>            <num>
# 1:        522             1000        0.4771355
# [1] "Mejor AUC Global: 0.929998649478534"

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.02
#
# $num_leaves
# [1] 522
#
# $min_data_in_leaf
# [1] 1000
#
# $feature_fraction
# [1] 0.4771355

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 09 11:16:55 PM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
