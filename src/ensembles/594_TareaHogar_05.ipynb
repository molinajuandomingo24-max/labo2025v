# %% [markdown]
# <a href="https://colab.research.google.com/github/molinajuandomingo24-max/labo2025v/blob/main/src/ensembles/594_TareaHogar_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Nov 08 07:53:35 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660368 35.3 1454480    77.7 1454480  77.7
# Vcells 1226537  9.4 8388608    64.0 1975136  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5941 # Cambiado a 5941 para nueva corrida
PARAM$semilla_primigenia <- 209353

# Definición de 5 semillas para estabilizar el resultado
PARAM$semillas_bo <- c(102191, 292267, 480731, 529681, 663149)
PARAM$indice_corrida <- 1 # Inicialización para el loop

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
# Parametros LightGBM fijos (mantengo la configuración actual)
PARAM$lgbm$param_fijos <- list(
  boosting= "gbdt",
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE,
  verbosity= -100,
  max_depth= -1L,
  min_gain_to_split= 0,
  min_sum_hessian_in_leaf= 0.001,
  lambda_l1= 0.0,
  lambda_l2= 0.0,
  max_bin= 31L,
  bagging_fraction= 1.0,
  pos_bagging_fraction= 1.0,
  neg_bagging_fraction= 1.0,
  is_unbalance= FALSE,
  scale_pos_weight= 1.0,
  drop_rate= 0.1,
  max_drop= 50,
  skip_drop= 0.5,
  extra_trees= FALSE,
  num_iterations= 1200,
  learning_rate= 0.02
  # Los 3 a optimizar no se colocan aquí, se definen en makeParamSet
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Definición de SOLO los 3 hiperparámetros principales a optimizar
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower= 16L, upper= 1024L), # Rango ajustado
  makeIntegerParam("min_data_in_leaf", lower= 1000L, upper= 8000L), # Rango ajustado
  makeNumericParam("feature_fraction", lower= 0.3, upper= 1.0) # Rango ajustado
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 30 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83349
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# La función EstimarGanancia_AUC_lightgbm se mantiene IGUAL
EstimarGanancia_AUC_lightgbm <- function(x) {

  # Obtener la semilla de la corrida actual
  semilla_actual <- PARAM$semillas_bo[PARAM$indice_corrida]

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)
  param_completo$seed <- semilla_actual # Asignar la semilla

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC, " (Semilla: ", semilla_actual, ")")

  return(AUC)
}

# %%
# Aquí comienza la configuración de la Bayesian Optimization

funcion_optimizar <- EstimarGanancia_AUC_lightgbm
configureMlr(show.learner.output= FALSE)

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar,
  minimize= FALSE,
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs,
  has.simple.signature= FALSE
)

# Definir el control MBO fuera del loop
kbayesiana_base <- "bayesiana"
ctrl <- makeMBOControl(save.on.disk.at.time= 600)
ctrl <- setMBOControlTermination(ctrl, iters= PARAM$hyperparametertuning$iteraciones)
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# Inicializo variables para rastrear el mejor resultado global
best_global_AUC <- -1
best_global_hyperparams <- NULL
resultados_semillas <- data.table()

# Loop para correr la BO con cada semilla
for (s in 1:length(PARAM$semillas_bo)) {

  PARAM$indice_corrida <- s
  semilla_actual <- PARAM$semillas_bo[s]
  kbayesiana <- paste0(kbayesiana_base, "_s", semilla_actual, ".RDATA")

  message(format(Sys.time(), "%a %b %d %X %Y"), " --- INICIANDO CORRIDA CON SEMILLA: ", semilla_actual, " ---")

  # Establecer la semilla para mlrMBO
  set.seed(semilla_actual)
  ctrl$save.file.path <- kbayesiana # Actualizar el path de guardado

  # inicio la optimizacion bayesiana
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)

  # Proceso el resultado de la corrida actual
  tb_bayesiana_actual <- as.data.table(bayesiana_salida$opt.path)
  setorder(tb_bayesiana_actual, -y)

  # Registro el mejor AUC de esta corrida
  mejor_auc_corrida <- tb_bayesiana_actual[1, y]

  # Guardo el resultado para el análisis global
  tb_bayesiana_actual[, iter := .I]
  tb_bayesiana_actual[, semilla := semilla_actual]
  resultados_semillas <- rbind(resultados_semillas, tb_bayesiana_actual, fill=TRUE)

  # Verifico si es el mejor resultado global
  if (mejor_auc_corrida > best_global_AUC) {
    best_global_AUC <- mejor_auc_corrida
    best_global_hyperparams <- tb_bayesiana_actual[
      1,
      setdiff(colnames(tb_bayesiana_actual),
        c("y","dob","eol","error.message","exec.time","ei","error.model",
          "train.time","prop.type","propose.time","se","mean","iter", "semilla")),
      with= FALSE
    ]
  }
}

# Almaceno los resultados finales de las 5 corridas

# Guardo el log completo de todas las semillas
fwrite(resultados_semillas,
  file= "BO_log_multi_semilla.txt",
  sep= "\t"
)

# Los mejores hiperparámetros globales
PARAM$out$lgbm$mejores_hiperparametros <- best_global_hyperparams
PARAM$out$lgbm$y_global <- best_global_AUC

write_yaml( PARAM, file="PARAM.yml")

print("Mejores Hiperparámetros Globales (entre 5 semillas):")
print(PARAM$out$lgbm$mejores_hiperparametros)
print(paste("Mejor AUC Global:", PARAM$out$lgbm$y_global))
# Out:
# Sat Nov 08 08:10:45 PM 2025 --- INICIANDO CORRIDA CON SEMILLA: 102191 ---
#
# Computing y column(s) for design. Not provided.
#
# Sat Nov 08 08:15:04 PM 2025 AUC 0.924884937516386 (Semilla: 102191)
#
# Sat Nov 08 08:17:17 PM 2025 AUC 0.9254769761488 (Semilla: 102191)
#
# Sat Nov 08 08:20:11 PM 2025 AUC 0.927413488919363 (Semilla: 102191)
#
# Sat Nov 08 08:24:16 PM 2025 AUC 0.926764546122119 (Semilla: 102191)
#
# Sat Nov 08 08:26:53 PM 2025 AUC 0.926727246353716 (Semilla: 102191)
#
# Sat Nov 08 08:28:58 PM 2025 AUC 0.925060566214915 (Semilla: 102191)
#
# Sat Nov 08 08:32:25 PM 2025 AUC 0.928664509530936 (Semilla: 102191)
#
# Sat Nov 08 08:35:01 PM 2025 AUC 0.926492557607236 (Semilla: 102191)
#
# Sat Nov 08 08:39:09 PM 2025 AUC 0.926797376630972 (Semilla: 102191)
#
# Sat Nov 08 08:42:28 PM 2025 AUC 0.922754255099174 (Semilla: 102191)
#
# Sat Nov 08 08:44:41 PM 2025 AUC 0.925067103974423 (Semilla: 102191)
#
# Sat Nov 08 08:49:06 PM 2025 AUC 0.928587656252651 (Semilla: 102191)
#
# [mbo] 0: num_leaves=658; min_data_in_leaf=5483; feature_fraction=0.526 : y = 0.925 : 258.8 secs : initdesign
#
# [mbo] 0: num_leaves=895; min_data_in_leaf=5854; feature_fraction=0.913 : y = 0.925 : 133.2 secs : initdesign
#
# [mbo] 0: num_leaves=197; min_data_in_leaf=2657; feature_fraction=0.658 : y = 0.927 : 174.0 secs : initdesign
#
# [mbo] 0: num_leaves=296; min_data_in_leaf=4216; feature_fraction=0.559 : y = 0.927 : 244.3 secs : initdesign
#
# [mbo] 0: num_leaves=575; min_data_in_leaf=3218; feature_fraction=0.742 : y = 0.927 : 157.1 secs : initdesign
#
# [mbo] 0: num_leaves=479; min_data_in_leaf=7223; feature_fraction=0.869 : y = 0.925 : 125.3 secs : initdesign
#
# [mbo] 0: num_leaves=981; min_data_in_leaf=1927; feature_fraction=0.632 : y = 0.929 : 207.1 secs : initdesign
#
# [mbo] 0: num_leaves=124; min_data_in_leaf=3356; feature_fraction=0.778 : y = 0.926 : 156.1 secs : initdesign
#
# [mbo] 0: num_leaves=701; min_data_in_leaf=4870; feature_fraction=0.463 : y = 0.927 : 247.6 secs : initdesign
#
# [mbo] 0: num_leaves=49; min_data_in_leaf=7852; feature_fraction=0.315 : y = 0.923 : 198.9 secs : initdesign
#
# [mbo] 0: num_leaves=822; min_data_in_leaf=6415; feature_fraction=0.982 : y = 0.925 : 133.4 secs : initdesign
#
# [mbo] 0: num_leaves=354; min_data_in_leaf=1307; feature_fraction=0.391 : y = 0.929 : 264.6 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 08:53:15 PM 2025 AUC 0.92826141862776 (Semilla: 102191)
#
# [mbo] 1: num_leaves=1024; min_data_in_leaf=1920; feature_fraction=0.37 : y = 0.928 : 248.6 secs : infill_ei
#
# Sat Nov 08 08:56:46 PM 2025 AUC 0.927546599566775 (Semilla: 102191)
#
# [mbo] 2: num_leaves=847; min_data_in_leaf=1257; feature_fraction=0.704 : y = 0.928 : 210.7 secs : infill_ei
#
# Sat Nov 08 09:01:24 PM 2025 AUC 0.929572879450039 (Semilla: 102191)
#
# [mbo] 3: num_leaves=810; min_data_in_leaf=1856; feature_fraction=0.476 : y = 0.93 : 277.5 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 09:06:14 PM 2025 AUC 0.927999939086711 (Semilla: 102191)
#
# [mbo] 4: num_leaves=667; min_data_in_leaf=1685; feature_fraction=0.512 : y = 0.928 : 289.5 secs : infill_ei
#
# Sat Nov 08 09:10:34 PM 2025 AUC 0.926083930573127 (Semilla: 102191)
#
# [mbo] 5: num_leaves=858; min_data_in_leaf=2604; feature_fraction=0.445 : y = 0.926 : 260.0 secs : infill_ei
#
# Sat Nov 08 09:15:05 PM 2025 AUC 0.928789174794812 (Semilla: 102191)
#
# [mbo] 6: num_leaves=749; min_data_in_leaf=1941; feature_fraction=0.563 : y = 0.929 : 270.4 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 09:18:10 PM 2025 AUC 0.928618177095163 (Semilla: 102191)
#
# [mbo] 7: num_leaves=573; min_data_in_leaf=1846; feature_fraction=0.763 : y = 0.929 : 185.3 secs : infill_ei
#
# Sat Nov 08 09:22:54 PM 2025 AUC 0.929148749595414 (Semilla: 102191)
#
# [mbo] 8: num_leaves=321; min_data_in_leaf=1847; feature_fraction=0.488 : y = 0.929 : 283.3 secs : infill_ei
#
# Sat Nov 08 09:27:38 PM 2025 AUC 0.928525125395227 (Semilla: 102191)
#
# [mbo] 9: num_leaves=805; min_data_in_leaf=1834; feature_fraction=0.531 : y = 0.929 : 283.8 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 09:30:53 PM 2025 AUC 0.928388052367125 (Semilla: 102191)
#
# [mbo] 10: num_leaves=798; min_data_in_leaf=1682; feature_fraction=0.868 : y = 0.928 : 194.6 secs : infill_ei
#
# Sat Nov 08 09:35:58 PM 2025 AUC 0.929489125511436 (Semilla: 102191)
#
# [mbo] 11: num_leaves=814; min_data_in_leaf=1004; feature_fraction=0.477 : y = 0.929 : 304.6 secs : infill_ei
#
# Sat Nov 08 09:40:28 PM 2025 AUC 0.926654874022561 (Semilla: 102191)
#
# [mbo] 12: num_leaves=814; min_data_in_leaf=2736; feature_fraction=0.479 : y = 0.927 : 269.1 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 09:45:04 PM 2025 AUC 0.928599161906973 (Semilla: 102191)
#
# [mbo] 13: num_leaves=751; min_data_in_leaf=1953; feature_fraction=0.468 : y = 0.929 : 275.3 secs : infill_ei
#
# Sat Nov 08 09:49:54 PM 2025 AUC 0.928469247926363 (Semilla: 102191)
#
# [mbo] 14: num_leaves=1013; min_data_in_leaf=1550; feature_fraction=0.481 : y = 0.928 : 290.2 secs : infill_ei
#
# Sat Nov 08 09:54:42 PM 2025 AUC 0.92869632635063 (Semilla: 102191)
#
# [mbo] 15: num_leaves=832; min_data_in_leaf=1545; feature_fraction=0.479 : y = 0.929 : 287.9 secs : infill_ei
#
# Saved the current state after iteration 16 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 09:59:45 PM 2025 AUC 0.930078181207283 (Semilla: 102191)
#
# [mbo] 16: num_leaves=74; min_data_in_leaf=1000; feature_fraction=0.476 : y = 0.93 : 301.9 secs : infill_ei
#
# Sat Nov 08 10:03:17 PM 2025 AUC 0.929868220702217 (Semilla: 102191)
#
# [mbo] 17: num_leaves=16; min_data_in_leaf=1027; feature_fraction=0.326 : y = 0.93 : 211.4 secs : infill_ei
#
# Sat Nov 08 10:07:56 PM 2025 AUC 0.929792883561305 (Semilla: 102191)
#
# [mbo] 18: num_leaves=61; min_data_in_leaf=1044; feature_fraction=0.408 : y = 0.93 : 279.2 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 10:12:09 PM 2025 AUC 0.928899842360521 (Semilla: 102191)
#
# [mbo] 19: num_leaves=16; min_data_in_leaf=1095; feature_fraction=0.486 : y = 0.929 : 252.7 secs : infill_ei
#
# Sat Nov 08 10:15:56 PM 2025 AUC 0.928830357890675 (Semilla: 102191)
#
# [mbo] 20: num_leaves=204; min_data_in_leaf=1000; feature_fraction=0.709 : y = 0.929 : 226.0 secs : infill_ei
#
# Sat Nov 08 10:18:50 PM 2025 AUC 0.927038950987483 (Semilla: 102191)
#
# [mbo] 21: num_leaves=721; min_data_in_leaf=2336; feature_fraction=0.821 : y = 0.927 : 173.8 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 10:23:25 PM 2025 AUC 0.929259609801582 (Semilla: 102191)
#
# [mbo] 22: num_leaves=76; min_data_in_leaf=1000; feature_fraction=0.39 : y = 0.929 : 274.4 secs : infill_ei
#
# Sat Nov 08 10:27:43 PM 2025 AUC 0.928412056566064 (Semilla: 102191)
#
# [mbo] 23: num_leaves=17; min_data_in_leaf=1024; feature_fraction=0.509 : y = 0.928 : 257.8 secs : infill_ei
#
# Sat Nov 08 10:30:48 PM 2025 AUC 0.927860817232859 (Semilla: 102191)
#
# [mbo] 24: num_leaves=483; min_data_in_leaf=3329; feature_fraction=0.625 : y = 0.928 : 184.0 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 10:35:38 PM 2025 AUC 0.929484851609373 (Semilla: 102191)
#
# [mbo] 25: num_leaves=87; min_data_in_leaf=1212; feature_fraction=0.466 : y = 0.929 : 289.9 secs : infill_ei
#
# Sat Nov 08 10:37:51 PM 2025 AUC 0.926230137890382 (Semilla: 102191)
#
# [mbo] 26: num_leaves=496; min_data_in_leaf=6130; feature_fraction=0.787 : y = 0.926 : 132.4 secs : infill_ei
#
# Sat Nov 08 10:42:13 PM 2025 AUC 0.928248473323429 (Semilla: 102191)
#
# [mbo] 27: num_leaves=803; min_data_in_leaf=1693; feature_fraction=0.394 : y = 0.928 : 261.2 secs : infill_ei
#
# Saved the current state after iteration 28 in the file bayesiana_s102191.RDATA.
#
# Sat Nov 08 10:46:19 PM 2025 AUC 0.929879575443357 (Semilla: 102191)
#
# [mbo] 28: num_leaves=404; min_data_in_leaf=1001; feature_fraction=0.3 : y = 0.93 : 245.5 secs : infill_ei
#
# Sat Nov 08 10:51:09 PM 2025 AUC 0.929087249347648 (Semilla: 102191)
#
# [mbo] 29: num_leaves=375; min_data_in_leaf=1365; feature_fraction=0.474 : y = 0.929 : 289.5 secs : infill_ei
#
# Sat Nov 08 10:56:05 PM 2025 AUC 0.929109418143725 (Semilla: 102191)
#
# [mbo] 30: num_leaves=243; min_data_in_leaf=1000; feature_fraction=0.452 : y = 0.929 : 295.6 secs : infill_ei
#
# Saved the final state in the file bayesiana_s102191.RDATA
#
# Saved the final state in the file bayesiana_s102191.RDATA
#
# Sat Nov 08 10:56:05 PM 2025 --- INICIANDO CORRIDA CON SEMILLA: 292267 ---
#
# Computing y column(s) for design. Not provided.
#
# Sat Nov 08 11:00:16 PM 2025 AUC 0.926023367462703 (Semilla: 292267)
#
# Sat Nov 08 11:03:10 PM 2025 AUC 0.924137479428862 (Semilla: 292267)
#
# Sat Nov 08 11:05:32 PM 2025 AUC 0.927286369955224 (Semilla: 292267)
#
# Sat Nov 08 11:10:12 PM 2025 AUC 0.927258768850418 (Semilla: 292267)
#
# Sat Nov 08 11:13:17 PM 2025 AUC 0.928768755616004 (Semilla: 292267)
#
# Sat Nov 08 11:15:44 PM 2025 AUC 0.926286666503888 (Semilla: 292267)
#
# Sat Nov 08 11:19:39 PM 2025 AUC 0.9250604989625 (Semilla: 292267)
#
# Sat Nov 08 11:23:08 PM 2025 AUC 0.926072212560712 (Semilla: 292267)
#
# Sat Nov 08 11:25:46 PM 2025 AUC 0.926758280523801 (Semilla: 292267)
#
# Sat Nov 08 11:28:01 PM 2025 AUC 0.925991943075457 (Semilla: 292267)
#
# Sat Nov 08 11:30:04 PM 2025 AUC 0.924471405116245 (Semilla: 292267)
#
# Sat Nov 08 11:34:15 PM 2025 AUC 0.928604132241402 (Semilla: 292267)
#
# [mbo] 0: num_leaves=300; min_data_in_leaf=2970; feature_fraction=0.566 : y = 0.926 : 251.1 secs : initdesign
#
# [mbo] 0: num_leaves=425; min_data_in_leaf=7388; feature_fraction=0.607 : y = 0.924 : 173.6 secs : initdesign
#
# [mbo] 0: num_leaves=608; min_data_in_leaf=4773; feature_fraction=0.79 : y = 0.927 : 142.4 secs : initdesign
#
# [mbo] 0: num_leaves=493; min_data_in_leaf=2251; feature_fraction=0.524 : y = 0.927 : 279.7 secs : initdesign
#
# [mbo] 0: num_leaves=797; min_data_in_leaf=1902; feature_fraction=0.754 : y = 0.929 : 185.5 secs : initdesign
#
# [mbo] 0: num_leaves=221; min_data_in_leaf=4233; feature_fraction=0.989 : y = 0.926 : 146.7 secs : initdesign
#
# [mbo] 0: num_leaves=568; min_data_in_leaf=6275; feature_fraction=0.434 : y = 0.925 : 234.9 secs : initdesign
#
# [mbo] 0: num_leaves=1010; min_data_in_leaf=5577; feature_fraction=0.323 : y = 0.926 : 209.2 secs : initdesign
#
# [mbo] 0: num_leaves=113; min_data_in_leaf=3503; feature_fraction=0.654 : y = 0.927 : 158.2 secs : initdesign
#
# [mbo] 0: num_leaves=912; min_data_in_leaf=5736; feature_fraction=0.839 : y = 0.926 : 134.6 secs : initdesign
#
# [mbo] 0: num_leaves=25; min_data_in_leaf=7830; feature_fraction=0.924 : y = 0.924 : 122.7 secs : initdesign
#
# [mbo] 0: num_leaves=723; min_data_in_leaf=1562; feature_fraction=0.36 : y = 0.929 : 251.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana_s292267.RDATA.
#
# Sat Nov 08 11:38:07 PM 2025 AUC 0.92866360134898 (Semilla: 292267)
#
# [mbo] 1: num_leaves=755; min_data_in_leaf=1000; feature_fraction=0.85 : y = 0.929 : 231.6 secs : infill_ei
#
# Sat Nov 08 11:43:15 PM 2025 AUC 0.928919695540783 (Semilla: 292267)
#
# [mbo] 2: num_leaves=906; min_data_in_leaf=1176; feature_fraction=0.535 : y = 0.929 : 307.4 secs : infill_ei
#
# Sat Nov 08 11:46:40 PM 2025 AUC 0.928875250790159 (Semilla: 292267)
#
# [mbo] 3: num_leaves=1024; min_data_in_leaf=1472; feature_fraction=0.772 : y = 0.929 : 204.2 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana_s292267.RDATA.
#
# Sat Nov 08 11:50:10 PM 2025 AUC 0.928293433397566 (Semilla: 292267)
#
# [mbo] 4: num_leaves=752; min_data_in_leaf=1313; feature_fraction=0.687 : y = 0.928 : 209.6 secs : infill_ei
#
# Sat Nov 08 11:54:03 PM 2025 AUC 0.927317524250123 (Semilla: 292267)
#
# [mbo] 5: num_leaves=1024; min_data_in_leaf=1816; feature_fraction=0.305 : y = 0.927 : 232.4 secs : infill_ei
#
# Sat Nov 08 11:58:59 PM 2025 AUC 0.929472202919527 (Semilla: 292267)
#
# [mbo] 6: num_leaves=920; min_data_in_leaf=1000; feature_fraction=0.447 : y = 0.929 : 295.7 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 12:03:55 AM 2025 AUC 0.929707189138795 (Semilla: 292267)
#
# [mbo] 7: num_leaves=714; min_data_in_leaf=1000; feature_fraction=0.437 : y = 0.93 : 295.9 secs : infill_ei
#
# Sun Nov 09 12:08:28 AM 2025 AUC 0.929794297756779 (Semilla: 292267)
#
# [mbo] 8: num_leaves=412; min_data_in_leaf=1000; feature_fraction=0.383 : y = 0.93 : 273.3 secs : infill_ei
#
# Sun Nov 09 12:12:23 AM 2025 AUC 0.929303498042666 (Semilla: 292267)
#
# [mbo] 9: num_leaves=17; min_data_in_leaf=1000; feature_fraction=0.405 : y = 0.929 : 233.6 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 12:15:37 AM 2025 AUC 0.928397048907431 (Semilla: 292267)
#
# [mbo] 10: num_leaves=1024; min_data_in_leaf=1814; feature_fraction=1 : y = 0.928 : 194.2 secs : infill_ei
#
# Sun Nov 09 12:20:14 AM 2025 AUC 0.928353163844438 (Semilla: 292267)
#
# [mbo] 11: num_leaves=590; min_data_in_leaf=1000; feature_fraction=0.383 : y = 0.928 : 275.9 secs : infill_ei
#
# Sun Nov 09 12:24:58 AM 2025 AUC 0.929961969531067 (Semilla: 292267)
#
# [mbo] 12: num_leaves=285; min_data_in_leaf=1000; feature_fraction=0.412 : y = 0.93 : 284.0 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 12:29:10 AM 2025 AUC 0.929121083897477 (Semilla: 292267)
#
# [mbo] 13: num_leaves=227; min_data_in_leaf=1000; feature_fraction=0.318 : y = 0.929 : 251.4 secs : infill_ei
#
# Sun Nov 09 12:34:02 AM 2025 AUC 0.929163453669031 (Semilla: 292267)
#
# [mbo] 14: num_leaves=369; min_data_in_leaf=1000; feature_fraction=0.433 : y = 0.929 : 291.7 secs : infill_ei
#
# Sun Nov 09 12:37:56 AM 2025 AUC 0.928601327225084 (Semilla: 292267)
#
# [mbo] 15: num_leaves=281; min_data_in_leaf=1000; feature_fraction=0.992 : y = 0.929 : 234.3 secs : infill_ei
#
# Saved the current state after iteration 16 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 12:42:32 AM 2025 AUC 0.929206430968406 (Semilla: 292267)
#
# [mbo] 16: num_leaves=278; min_data_in_leaf=1000; feature_fraction=0.382 : y = 0.929 : 275.0 secs : infill_ei
#
# Sun Nov 09 12:46:50 AM 2025 AUC 0.929614283827627 (Semilla: 292267)
#
# [mbo] 17: num_leaves=303; min_data_in_leaf=1001; feature_fraction=0.338 : y = 0.93 : 258.1 secs : infill_ei
#
# Sun Nov 09 12:50:54 AM 2025 AUC 0.928937965688116 (Semilla: 292267)
#
# [mbo] 18: num_leaves=413; min_data_in_leaf=1415; feature_fraction=0.33 : y = 0.929 : 243.3 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 12:54:50 AM 2025 AUC 0.927366511894932 (Semilla: 292267)
#
# [mbo] 19: num_leaves=578; min_data_in_leaf=1000; feature_fraction=1 : y = 0.927 : 235.1 secs : infill_ei
#
# Sun Nov 09 12:59:29 AM 2025 AUC 0.929759358106956 (Semilla: 292267)
#
# [mbo] 20: num_leaves=291; min_data_in_leaf=1004; feature_fraction=0.4 : y = 0.93 : 279.2 secs : infill_ei
#
# Sun Nov 09 01:04:32 AM 2025 AUC 0.928353041067836 (Semilla: 292267)
#
# [mbo] 21: num_leaves=798; min_data_in_leaf=1000; feature_fraction=0.462 : y = 0.928 : 302.5 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 01:06:39 AM 2025 AUC 0.924535210320134 (Semilla: 292267)
#
# [mbo] 22: num_leaves=987; min_data_in_leaf=7552; feature_fraction=0.749 : y = 0.925 : 125.8 secs : infill_ei
#
# Sun Nov 09 01:10:31 AM 2025 AUC 0.927942513592344 (Semilla: 292267)
#
# [mbo] 23: num_leaves=400; min_data_in_leaf=1001; feature_fraction=0.909 : y = 0.928 : 232.2 secs : infill_ei
#
# Sun Nov 09 01:15:21 AM 2025 AUC 0.929571074977974 (Semilla: 292267)
#
# [mbo] 24: num_leaves=139; min_data_in_leaf=1001; feature_fraction=0.436 : y = 0.93 : 289.8 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 01:19:56 AM 2025 AUC 0.928507625820299 (Semilla: 292267)
#
# [mbo] 25: num_leaves=877; min_data_in_leaf=1367; feature_fraction=0.418 : y = 0.929 : 274.5 secs : infill_ei
#
# Sun Nov 09 01:24:30 AM 2025 AUC 0.928752313702054 (Semilla: 292267)
#
# [mbo] 26: num_leaves=303; min_data_in_leaf=1591; feature_fraction=0.436 : y = 0.929 : 273.0 secs : infill_ei
#
# Sun Nov 09 01:28:41 AM 2025 AUC 0.925321689056741 (Semilla: 292267)
#
# [mbo] 27: num_leaves=897; min_data_in_leaf=6621; feature_fraction=0.527 : y = 0.925 : 250.7 secs : infill_ei
#
# Saved the current state after iteration 28 in the file bayesiana_s292267.RDATA.
#
# Sun Nov 09 01:33:49 AM 2025 AUC 0.929272713233708 (Semilla: 292267)
#
# [mbo] 28: num_leaves=1024; min_data_in_leaf=1001; feature_fraction=0.481 : y = 0.929 : 307.4 secs : infill_ei
#
# Sun Nov 09 01:38:16 AM 2025 AUC 0.929207512136539 (Semilla: 292267)
#
# [mbo] 29: num_leaves=397; min_data_in_leaf=1004; feature_fraction=0.358 : y = 0.929 : 266.6 secs : infill_ei
#
# Sun Nov 09 01:42:07 AM 2025 AUC 0.929312400979013 (Semilla: 292267)
#
# [mbo] 30: num_leaves=281; min_data_in_leaf=1002; feature_fraction=0.771 : y = 0.929 : 230.7 secs : infill_ei
#
# Saved the final state in the file bayesiana_s292267.RDATA
#
# Saved the final state in the file bayesiana_s292267.RDATA
#
# Sun Nov 09 01:42:07 AM 2025 --- INICIANDO CORRIDA CON SEMILLA: 480731 ---
#
# Computing y column(s) for design. Not provided.
#
# Sun Nov 09 01:45:00 AM 2025 AUC 0.925658341836816 (Semilla: 480731)
#
# Sun Nov 09 01:49:15 AM 2025 AUC 0.927882371044252 (Semilla: 480731)
#
# Sun Nov 09 01:53:19 AM 2025 AUC 0.926661512198316 (Semilla: 480731)
#
# Sun Nov 09 01:55:35 AM 2025 AUC 0.925810994046117 (Semilla: 480731)
#
# Sun Nov 09 01:59:02 AM 2025 AUC 0.92484845813827 (Semilla: 480731)
#
# Sun Nov 09 02:02:33 AM 2025 AUC 0.927055768782755 (Semilla: 480731)
#
# Sun Nov 09 02:05:20 AM 2025 AUC 0.927108054397008 (Semilla: 480731)
#
# Sun Nov 09 02:09:29 AM 2025 AUC 0.924881933292519 (Semilla: 480731)
#
# Sun Nov 09 02:13:07 AM 2025 AUC 0.927974871427444 (Semilla: 480731)
#
# Sun Nov 09 02:15:12 AM 2025 AUC 0.924492602418137 (Semilla: 480731)
#
# Sun Nov 09 02:19:26 AM 2025 AUC 0.928290372379482 (Semilla: 480731)
#
# Sun Nov 09 02:21:43 AM 2025 AUC 0.925073735632993 (Semilla: 480731)
#
# [mbo] 0: num_leaves=601; min_data_in_leaf=2488; feature_fraction=0.678 : y = 0.926 : 172.7 secs : initdesign
#
# [mbo] 0: num_leaves=644; min_data_in_leaf=3895; feature_fraction=0.553 : y = 0.928 : 254.7 secs : initdesign
#
# [mbo] 0: num_leaves=724; min_data_in_leaf=4750; feature_fraction=0.456 : y = 0.927 : 244.0 secs : initdesign
#
# [mbo] 0: num_leaves=226; min_data_in_leaf=5633; feature_fraction=0.709 : y = 0.926 : 136.1 secs : initdesign
#
# [mbo] 0: num_leaves=40; min_data_in_leaf=7025; feature_fraction=0.333 : y = 0.925 : 206.7 secs : initdesign
#
# [mbo] 0: num_leaves=870; min_data_in_leaf=4482; feature_fraction=0.594 : y = 0.927 : 211.8 secs : initdesign
#
# [mbo] 0: num_leaves=497; min_data_in_leaf=2897; feature_fraction=0.774 : y = 0.927 : 166.2 secs : initdesign
#
# [mbo] 0: num_leaves=280; min_data_in_leaf=6561; feature_fraction=0.521 : y = 0.925 : 249.7 secs : initdesign
#
# [mbo] 0: num_leaves=832; min_data_in_leaf=1233; feature_fraction=0.953 : y = 0.928 : 218.2 secs : initdesign
#
# [mbo] 0: num_leaves=135; min_data_in_leaf=7557; feature_fraction=0.882 : y = 0.924 : 124.3 secs : initdesign
#
# [mbo] 0: num_leaves=361; min_data_in_leaf=1940; feature_fraction=0.401 : y = 0.928 : 254.8 secs : initdesign
#
# [mbo] 0: num_leaves=1020; min_data_in_leaf=5776; feature_fraction=0.93 : y = 0.925 : 136.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 02:25:46 AM 2025 AUC 0.927647030424781 (Semilla: 480731)
#
# [mbo] 1: num_leaves=272; min_data_in_leaf=1633; feature_fraction=0.334 : y = 0.928 : 242.5 secs : infill_ei
#
# Sun Nov 09 02:29:53 AM 2025 AUC 0.928272578682491 (Semilla: 480731)
#
# [mbo] 2: num_leaves=370; min_data_in_leaf=2936; feature_fraction=0.415 : y = 0.928 : 246.6 secs : infill_ei
#
# Sun Nov 09 02:34:10 AM 2025 AUC 0.927682486460266 (Semilla: 480731)
#
# [mbo] 3: num_leaves=854; min_data_in_leaf=2405; feature_fraction=0.417 : y = 0.928 : 256.0 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 02:38:19 AM 2025 AUC 0.926438971347004 (Semilla: 480731)
#
# [mbo] 4: num_leaves=512; min_data_in_leaf=2481; feature_fraction=0.402 : y = 0.926 : 249.2 secs : infill_ei
#
# Sun Nov 09 02:42:12 AM 2025 AUC 0.926248645392382 (Semilla: 480731)
#
# [mbo] 5: num_leaves=400; min_data_in_leaf=3722; feature_fraction=0.581 : y = 0.926 : 232.5 secs : infill_ei
#
# Sun Nov 09 02:46:10 AM 2025 AUC 0.927250167427583 (Semilla: 480731)
#
# [mbo] 6: num_leaves=347; min_data_in_leaf=2773; feature_fraction=0.373 : y = 0.927 : 237.5 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana_s480731.RDATA.
#
# Sun Nov 09 02:50:39 AM 2025 AUC 0.927678339102418 (Semilla: 480731)
#
# [mbo] 7: num_leaves=373; min_data_in_leaf=1408; feature_fraction=0.416 : y = 0.928 : 268.7 secs : infill_ei

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
